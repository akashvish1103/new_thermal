# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Akash Vishwakarma\Desktop\new_thermal\data\aditi_roi_temperatures.csv")
df.sample(5)
# Out:
#       frame  left_eye_temp  right_eye_temp  forehead_temp  nose_temp  \
# 636     636      37.093489       36.840157      35.303779  34.000649
# 2667   2667      36.922637       36.631010      35.021753  35.544383
# 896     896      37.220155       36.742948      35.323772  34.381861
# 309     309      37.343876       36.962404      35.523198  34.423448
# 432     432      37.277597       36.937366      35.448850  34.403001
#
#       left_cheek_temp  right_cheek_temp
# 636         34.267575         34.193982
# 2667        34.648016         34.819333
# 896         34.312620         34.264032
# 309         34.248955         34.256358
# 432         34.256454         34.291999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2848 entries, 0 to 2847
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   frame             2848 non-null   int64
#  1   left_eye_temp     2836 non-null   float64
#  2   right_eye_temp    2845 non-null   float64
#  3   forehead_temp     2784 non-null   float64
#  4   nose_temp         2844 non-null   float64
#  5   left_cheek_temp   2841 non-null   float64
#  6   right_cheek_temp  2845 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 155.9 KB

# %%
df.isna().sum()
# Out:
# frame                0
# left_eye_temp       12
# right_eye_temp       3
# forehead_temp       64
# nose_temp            4
# left_cheek_temp      7
# right_cheek_temp     3
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# frame               0
# left_eye_temp       0
# right_eye_temp      0
# forehead_temp       0
# nose_temp           0
# left_cheek_temp     0
# right_cheek_temp    0
# dtype: int64

# %%
plt.plot(df['forehead_temp'])

# %%
df
# Out:
#       frame  left_eye_temp  right_eye_temp  forehead_temp  nose_temp  \
# 0         0      37.295271       36.788606      35.350540  33.645256
# 1         1      37.314419       36.918218      35.376890  33.706596
# 2         2      37.314419       36.937366      35.373236  33.683724
# 3         3      37.329147       36.931474      35.378458  33.762045
# 4         4      37.329147       36.894653      35.370136  33.716127
# ...     ...            ...             ...            ...        ...
# 2843   2843      36.838684       36.522018      34.956602  35.166637
# 2844   2844      36.823955       36.572095      34.963645  35.146883
# 2845   2845      36.812172       36.572095      34.968433  35.181019
# 2846   2846      36.790079       36.547057      34.941287  35.139952
# 2847   2847      36.801862       36.560313      34.945944  35.147057
#
#       left_cheek_temp  right_cheek_temp
# 0           33.836486         33.892849
# 1           33.785988         33.901683
# ...

# %%
df.mean()
# Out:
# frame               1432.332256
# left_eye_temp         37.027055
# right_eye_temp        36.734070
# forehead_temp         35.171727
# nose_temp             35.053388
# left_cheek_temp       34.336075
# right_cheek_temp      34.443445
# dtype: float64

# %%
df['left_eye_temp'].std()
# Out:
# 0.14227520274321698

# %%
df['right_eye_temp'].std()
# Out:
# 0.12530300385203771

# %% [markdown]
# # Data Preperation
