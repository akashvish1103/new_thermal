# %%
import numpy as np

# %%
arr = np.random.randint(0, 255, 800)

# %%
arr.reshape(40, 20)
# Out:
# array([[ 65,  95,  48, 219,  62, 162, 166,  96, 235, 160,  72, 181,  29,
#         166,  77, 146, 150, 189,  37, 241],
#        [ 77,  77,  62, 180, 190,  46, 148,  48,  94, 196, 172, 113, 218,
#          70, 100, 138,  46, 251, 113,  86],
#        [ 46,  55, 235, 111,  88,  29, 102, 197, 217, 145,  43, 132,  92,
#         135, 118, 234,  54, 109,  83,  23],
#        [ 30, 206, 169, 237,  73, 157, 198, 123, 119,  18, 125, 250, 162,
#          86,  49, 246,  15,  81,  95, 236],
#        [108,  79, 169,  97, 233, 194,  89,  15, 134,   3, 215,  94, 219,
#         151, 204, 188, 143,  40,  18, 169],
#        [252, 136,  60,  78, 126,   8, 139,   7,  81,  63, 231,  73,  44,
#         215, 211, 215,  69, 118, 186, 246],
#        [165, 146, 243, 157,  41, 247,  74, 240,  73, 158, 193, 192, 239,
#         223,  68,  47, 161, 174, 185,  37],
#        [101,  85,   7, 156,  83, 198, 156, 186,  65, 217,  90, 201,  19,
#         185,  82, 140, 237, 173,   3,  18],
# ...

# %%
import cv2
import numpy as np
arr = np.random.randint(0, 255, 80000).reshape(400, 200).astype(np.uint8)
cv2.imshow("My window", arr)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
arr2 = arr[300:400,:]
cv2.imshow("My window", arr2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
arr
# Out:
# array([[ 21, 112, 216, ..., 203,  45, 112],
#        [101,  92, 167, ...,  19, 237, 254],
#        [129, 147,  95, ..., 191, 245, 127],
#        ...,
#        [ 17, 119, 205, ..., 255, 255, 255],
#        [ 15,  60, 162, ..., 255, 255, 255],
#        [104, 132, 134, ..., 255, 255, 255]], dtype=uint8)
