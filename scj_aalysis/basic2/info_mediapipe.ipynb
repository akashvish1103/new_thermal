# %%
import mediapipe as mp

# %%
mp_face_mesh = mp.solutions.face_mesh

# %%
face_mesh_a = mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    refine_landmarks=True
    )

# %%
type(face_mesh_a)
# Out:
# mediapipe.python.solutions.face_mesh.FaceMesh

# %%
import cv2

image_path = r"C:\Users\Akash Vishwakarma\Pictures\Screenshots\Screenshot 2025-06-30 125137.png"
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
results = face_mesh_a.process(image)
print(type(results))
# Out:
# <class 'type'>

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
print(type(results))
# Out:
# <class 'type'>

# %%
import cv2

image_path = r"C:\Users\Akash Vishwakarma\Pictures\Screenshots\Screenshot 2025-06-30 125137.png"
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
results = face_mesh.process(image)
print(type(results))
# Out:
# <class 'type'>

# %%
print(results)
print(repr(results))
print(type(results))
print(results is None)
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'type'>
# False

# %%
resu
