# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Akash Vishwakarma\Desktop\new_thermal\data\aditi_roi_temperatures.csv")

# %%
df.sample(5)
# Out:
#       frame  left_eye_temp  right_eye_temp  forehead_temp  nose_temp  \
# 1900   1900      36.943257       36.707599      35.019393  35.880369
# 644     644      37.120001       36.738529      35.316473  34.184151
# 2185   2185      36.935893       36.822482      35.059150  35.650256
# 2071   2071      36.843102       36.558840      34.874487  35.748678
# 1340   1340      37.059613       36.891707      35.259439  35.284639
#
#       left_cheek_temp  right_cheek_temp
# 1900        34.400871         34.579940
# 644         34.369497         34.181462
# 2185        34.585393         34.705005
# 2071        34.409493         34.525848
# 1340        34.197952         34.517540

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2848 entries, 0 to 2847
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   frame             2848 non-null   int64
#  1   left_eye_temp     2836 non-null   float64
#  2   right_eye_temp    2845 non-null   float64
#  3   forehead_temp     2784 non-null   float64
#  4   nose_temp         2844 non-null   float64
#  5   left_cheek_temp   2841 non-null   float64
#  6   right_cheek_temp  2845 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 155.9 KB

# %%
df.isna().sum()
# Out:
# frame                0
# left_eye_temp       12
# right_eye_temp       3
# forehead_temp       64
# nose_temp            4
# left_cheek_temp      7
# right_cheek_temp     3
# dtype: int64
